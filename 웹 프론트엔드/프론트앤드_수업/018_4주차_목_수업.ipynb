# %% [markdown]
# # 수업
#
# ## immutable.js
#
# [npm install immutable](https://immutable-js.com/)
#
# ## react-route start
# [코드 참고용](https://reactrouter.com/web/guides/quick-start)

# %% [markdown]
# ## 캡슐화
#
# - encapsulation
#   - 파일 내 원하는 함수만
#     - `export default 함수명` 으로 보내고 나머지 봉인!
#
# ## router
#
# ```js
#   import { BrowserRouter as Router } from "react-router-dom";
# ```
#
# 가장 외부에 있어야 하는 태그
# - index.js 에서 작업함
#
# ## route
#
# ```js
#   return (
#     <div>
#       <Header title="html"></Header>
#       <Nav src={topics} onSelect={selectHandler}></Nav>
#       <Route exact path="/">
#         <ArticleTag title="Welcome" body="Hello, WEB" />
#       </Route>
#       <Route path="/create">
#         <Create onCreate={createHandler}></Create>
#       </Route>
#       <Route path="/read/:id">
#         <Read topics={topics}/>
#       </Route>
#       <Route path="/update/:id">Update</Route>
#       <Controll onChangeMode={changeHandler} />
#     </div>
#   );
# ```
#
# route 구조
#
# ## useHistory
#
# ```js
#   const history = useHistory();
#
#   ...
#
#   history.push("/read/" + newTopics.length)
# ```
#
# useHistory 로 url 을 이동할 수 있다.
#
# ## useParams
#
# ```js
#   const params = useParams();
# ```

# %% [markdown]
# ```js
#     class App extends Component{
#         state = {
#             count : 0,
#         };
#
#         countUpdate(n) {
#             this.setState({
#                 count: n,
#             });
#         };
#     }
#     render() {
#         const { count } = this.state;
#         return ...
#     }
#
# ```

# %% [markdown]
# import ReactDOM from 'react-dom';
# import './index.css';
# import * as serviceWorker from './serviceWorker';
# import React from 'react';
#
# class Example extends React.Component {
#   constructor(props) {
#     super(props);
#     this.state = {
#         count : 0
#     }
#     this.setState = () => {
#         console.log(this.state.count)
#         this.state.count++;
#     }
#     // count의 state를 0으로 설정하세요.
#   }
#
#   render() {
#     return (
#       <div>
#         {/* count의 state를 출력하세요. */}
#         <p>You clicked {this.state.count} times</p>
#         {/* setState()를 이용해 버튼 클릭 시 count가 1 증가하는 코드를 작성하세요. */}
#         <button onClick={() => {
#           this.setState();
#           setState();
#           }
#         }>Click me</button>
#       </div>
#     );
#   }
# }
#
# ReactDOM.render(<Example />,document.getElementById('root'));
#
# serviceWorker.unregister();
