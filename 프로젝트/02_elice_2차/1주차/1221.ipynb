# %% [markdown]
# # 오피스아워 질문
#
# 1. 추천 시스템
#    - 영화, 드라마, 예능 추천 구현 고민
# 2. 데이터 크롤링
# 3. 이미지 주소 관련 질문
# 4. 데이터 분석 포지션에서 팀장 (기획) 관리
#
# b2c
# 좋아하는 컨텐츠
#
# 정확도 낮다.
#
#
# 규칙기반으로 추천진행
# 평점을 누적(구축)
#
# 협업 필터링은 불가...
# - 매우 많은 데이터
#
# 10개 점수를 매기고
# 그 뒤 추천이 무의미
#
# 키워드()
#
# 감독 : 봉중호 -> 기생충 1점, 설국열차 1점
# 배우 : 최우식 -> 기생충 1점
#
#
# - 포지션
#
# - 웹개발
#   - 기획방향 -> 웹 완성도!!!
#   - 추천, 모델링 -> 여유
#
# - Doc2vec
# - TF-idf
#
# 시놉시스 + 뎃글 등등 추가하자.
#
# KDX
#
#
# 논문 참고 - 코로나 시대 OTT 사용자 증가
# OTT 사용자 증가에 따른 ... 개연성 !

# %% [markdown]
# ## 해결한일
#
# 1. 사이트 찾기
# 2. 사이트 정보 진위 여부 확인
#    - 네이버 시리즈 맴버십 누락. (볼만한 영화 없음)
#    - 디즈니 스파이더맨 없음
#    - 웨이브 개별 구매 상품 있음
#    - 추가적으로 한국 OTT는 개별 수집해야함

# %% [markdown]
# ## 내일 해야하는일
#
# 1. 데이터 컬럼 설명하기.
# 1. 데이터 크롤링
# 2. 수집 데이터 컬럼 전달(이미지 링크 포함)
# 3. 추천 시스템 구현
# 4. OTT 사이트 전달
