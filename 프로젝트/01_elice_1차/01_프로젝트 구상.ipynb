# %% [markdown]
# # 프로젝트 해야할 일
#
# - 출석체크
#
# ## gitlab
#
# - 일일회고(Wiki)
#   - 일반적으로 해당 프로젝트에 대한 백과사전을 남기기 위한 목적으로 사용
#
# - 오프스아워(Issue)
#   - 일반적인 용법이 따로 없을 정도로 자유도가 높은 기능입니다.
#   - 주로 request todo features, bugreporting, discussion등을 위해 사용합니다.
#   - 주로 질문을 위해 사용
#   - 프로젝트 진행 시, 어떠한 상황, 문제 또는 계획을 개발 할 예정이라는 것을 알려주는 이정표입니다.
#
# - Merge Request(코드리뷰)
#   - 일반적으로 PR(Pull request)로 알려져있습니다.
#   - 대표적인 use case는
#     - dev branch -> master branch로의 병합 요청입니다.
#   - MR하지 않는다면) local rapo에서
#     - dev -> master merge 이후 remote로 push하는 방법도 있습니다.
#   - 위와 같은 방법을 사용하지 않고 MR이라는 복잡한 방법을 사용하는 이유는...
#
# - 프로젝트 구조
#   - 1. master Branch
#   - 2. Dev Branch
#   - 3. Feature Branch
#
# - README.md
#   - 포함되어야 하는 내용
#     - 구성 안내, 기술 스택 등
#     - 프로젝트 기능 설명
#     - 프로젝트 구성도
#     - 프로젝트 팀원 역활 분ㄴ담
#     - 버전
#
# - GitLab issue
#   - 개발 중 어려웠거나 궁금한 내용을 매일 오후 6시까지 등록
#   - Issue의 Assignee을 오피스아워 진핸자 코치님 태크
#
#
# ## 프로젝트 디자인
#
# - 회원가입
#   - 네이버 참고
# - 시작 페이지
#   - 메인 페이지, 광고, 책소개, 회원가입, 로고
#   - 서울 도서관, 알라딘 참고
#
# ## 사용 패키지 정리
#
# - sudo apt update
# - sudo apt install nodejs
#
# - sudo apt-get update
# - sudo apt-get python3.8
# - sudo apt intall python3-pip
# - pip3 install flask
# - pip3 install requests
# - pip3 install Flask-SQLAlchemy
# - pip3 install flask_bcrypt
# -
# - pip3 install pandas
# - pip3 install openpyxl
# - pip3 install cryptography
#
# ?
# - python -m pip install --upgrade pip
#
# - db 관리
#
# ```sql
# -- MySQL Workbench Forward Engineering
#
# SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;
# SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0;
# SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';
#
# -- -----------------------------------------------------
# -- Schema elice_book_rental
# -- -----------------------------------------------------
#
# -- -----------------------------------------------------
# -- Schema elice_book_rental
# -- -----------------------------------------------------
# CREATE SCHEMA IF NOT EXISTS `elice_book_rental` DEFAULT CHARACTER SET utf8mb4 COLLATE utf8mb4_bin ;
# USE `elice_book_rental` ;
#
# -- -----------------------------------------------------
# -- Table `elice_book_rental`.`user`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `elice_book_rental`.`user` (
#   `id` INT NOT NULL AUTO_INCREMENT,
#   `user_id` VARCHAR(30) NOT NULL,
#   `user_pw` TEXT NOT NULL,
#   `user_name` VARCHAR(20) NOT NULL,
#   `user_nickname` VARCHAR(30) NOT NULL,
#   PRIMARY KEY (`id`),
#   UNIQUE INDEX `user_id_UNIQUE` (`user_id` ASC) VISIBLE,
#   UNIQUE INDEX `user_nickname_UNIQUE` (`user_nickname` ASC) VISIBLE)
# ENGINE = InnoDB;
#
#
# -- -----------------------------------------------------
# -- Table `elice_book_rental`.`book`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `elice_book_rental`.`book` (
#   `id` INT NOT NULL AUTO_INCREMENT,
#   `book_name` VARCHAR(100) NOT NULL,
#   `book_publisher` VARCHAR(40) NOT NULL,
#   `book_author` VARCHAR(30) NOT NULL,
#   `book_publication_date` TIMESTAMP NOT NULL,
#   `book_pages` INT NOT NULL,
#   `book_isbn` BIGINT NOT NULL,
#   `book_description` TEXT NOT NULL,
#   `book_link` VARCHAR(60) NOT NULL,
#   PRIMARY KEY (`id`))
# ENGINE = InnoDB;
#
#
# -- -----------------------------------------------------
# -- Table `elice_book_rental`.`book_stock`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `elice_book_rental`.`book_stock` (
#   `book_serial_number` INT NOT NULL AUTO_INCREMENT,
#   `book_id` INT NOT NULL,
#   `is_rental` TINYINT NOT NULL,
#   PRIMARY KEY (`book_serial_number`),
#   INDEX `fk_book_stock_book_idx` (`book_id` ASC) VISIBLE,
#   CONSTRAINT `fk_book_stock_book`
#     FOREIGN KEY (`book_id`)
#     REFERENCES `elice_book_rental`.`book` (`id`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION)
# ENGINE = InnoDB;
#
#
# -- -----------------------------------------------------
# -- Table `elice_book_rental`.`book_rental`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `elice_book_rental`.`book_rental` (
#   `id` INT NOT NULL AUTO_INCREMENT,
#   `user_id` INT NOT NULL,
#   `book_serial_number` INT NOT NULL,
#   `book_name` VARCHAR(100) NOT NULL,
#   `rental_date` TIMESTAMP NULL DEFAULT NOW(),
#   `return_date` TIMESTAMP NULL,
#   `is_return` TINYINT NOT NULL,
#   PRIMARY KEY (`id`),
#   INDEX `fk_book_rental_user1_idx` (`user_id` ASC) VISIBLE,
#   INDEX `fk_book_rental_book_stock1_idx` (`book_serial_number` ASC) VISIBLE,
#   CONSTRAINT `fk_book_rental_user1`
#     FOREIGN KEY (`user_id`)
#     REFERENCES `elice_book_rental`.`user` (`id`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION,
#   CONSTRAINT `fk_book_rental_book_stock1`
#     FOREIGN KEY (`book_serial_number`)
#     REFERENCES `elice_book_rental`.`book_stock` (`book_serial_number`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION)
# ENGINE = InnoDB;
#
#
# -- -----------------------------------------------------
# -- Table `elice_book_rental`.`book_evaluation`
# -- -----------------------------------------------------
# CREATE TABLE IF NOT EXISTS `elice_book_rental`.`book_evaluation` (
#   `id` INT NOT NULL,
#   `book_id` INT NOT NULL,
#   `user_id` INT NOT NULL,
#   `book_evaluation` INT NOT NULL,
#   `evaluationcol_contente` TEXT NOT NULL,
#   `evaluation_time` TIMESTAMP NULL DEFAULT NOW(),
#   PRIMARY KEY (`id`),
#   INDEX `fk_book_evaluation_user1_idx` (`user_id` ASC) VISIBLE,
#   INDEX `fk_book_evaluation_book1_idx` (`book_id` ASC) VISIBLE,
#   CONSTRAINT `fk_book_evaluation_book1`
#     FOREIGN KEY (`book_id`)
#     REFERENCES `elice_book_rental`.`book` (`id`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION,
#   CONSTRAINT `fk_book_evaluation_user1`
#     FOREIGN KEY (`user_id`)
#     REFERENCES `elice_book_rental`.`user` (`id`)
#     ON DELETE NO ACTION
#     ON UPDATE NO ACTION)
# ENGINE = InnoDB;
#
#
# SET SQL_MODE=@OLD_SQL_MODE;
# SET FOREIGN_KEY_CHECKS=@OLD_FOREIGN_KEY_CHECKS;
# SET UNIQUE_CHECKS=@OLD_UNIQUE_CHECKS;
#
#
# ```
#
#
# [외부키](https://velog.io/@sangmin7648/%EC%98%A4%EB%8A%98%EC%9D%98-%EB%B0%B0%EC%9B%80-035)

# %%
User
  id
  email
  username
  rent_set

Rent
  id
  user = relationship("user", backref)
  rented_date
  book = relationship("book")


email = "gimbek9@gmail.com"

user = User.query.filter_by(email=email)
user.rent_set[0].rented_date
rent.book.name
# Out:
#   File "<ipython-input-20-667825312ee9>", line 1
#     user = User...
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 설계 구상 시연
#
# 서버배포가 불가능할시 로컬도 가능
#
# 기능
# - 왜?
#   - 이유
#   - 테이블 나눈 이유
#     - 추가 기능을 추가하기 위해
#
# 나만의 팁
#
# ppt도 만들어야함
# 10분 발표 내용 고민
