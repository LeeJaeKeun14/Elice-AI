# %% [markdown]
# # 플라스크 환경 구현
#
# ## 코드 해석
#
# - html
#
# ```js
#     fetch('/topics')  // 가져온다.
#         .then(function(type){  // 타입은
#             return type.json();  // json 형식이다.  예) type.text()
#         }) // 이를 해석해서 js 가 읽을 수 있는 타입으로 반환해준다.
# ```
#
# - axios 가 상위호환
#
# - JSON 으로 바꾸기
#
# ```js
#     JSON.parse(`{
#         "title" : "react",
#         "body" : "react is .."
#     }`)
#
# ```
#
# ### restapi
#
# [이고잉 영상](https://www.youtube.com/watch?v=PmY3dWcCxXI)
#
#
# ### react 연동
#
# - package.json 파일
#
# ```json
# {
#     // ...
#     "proxy": "http://localhost:5000/",
#     // ...
# }
# ```
#
# - react 파일
#
# ```js
#   useEffect(function(){
#     function 데이터타입결정(type){
#       return type.json()
#     }
#     function 데이터받기(result){
#         console.log(result);
#         setTopics(result)
#     }
#     fetch('http://localhost:3000/topics').then(데이터타입결정).then(데이터받기)
#   }, [])
# ```
