# %%
import pandas as pd

# %%
df = pd.DataFrame([{"나이":12, "이름": "이재근"}])

# %%
df = pd.read_csv("./서울특별시 일반음식점 인허가 정보.csv", encoding="CP949")
# Out:
# C:\Users\ljkea\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (25,28,29,30,36,39,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(1)
# Out:
#    개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3000000  3000000-101-2001-11784  20010214      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명  폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명  보증액  \
# 0         1      영업   NaN     NaN  ...        NaN        NaN     NaN  NaN
#
#    월세액 다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식  홈페이지
# 0  NaN        N  34.56       NaN      NaN   NaN
#
# [1 rows x 44 columns]

# %%
# pd.set_option("display.max_rows", 999)
pd.set_option('display.max_rows', 100)

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
#        '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
#        '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
df["사업장명"]
# Out:
# 0                      일식동경
# 1                        상해
# 2                        미쿠
# 3                        짱구
# 4                여름엔빙수겨울엔떡국
#                 ...
# 469866    까페플라넷(CafePlanet)
# 469867                 강원식당
# 469868              우리밀 칼국수
# 469869                   북경
# 469870               마리채생고기
# Name: 사업장명, Length: 469871, dtype: object

# %%
list(df["사업장명"].unique())
# Out:
# ['일식동경',
#  '상해',
#  '미쿠',
#  '짱구',
#  '여름엔빙수겨울엔떡국',
#  '카페디퍼',
#  '메이크데이(MakeDay)',
#  '달의 작업실(Lalune)',
#  '숯칼 도산 숯닭갈비',
#  '테트리스찜닭 수유미아점',
#  '블러프라운지',
#  '싱싱호프',
#  '탐라정성돈카츠(탐정돈)',
#  '찬모일기',
#  '보스턴피자',
#  '올리브커피숍',
#  '먹거리 곱창전골',
#  '주문바다요',
#  '커피할루카',
#  '식껍선유도역점',
#  '반상회성수',
#  '무심',
#  '우주에프앤비 광진점',
#  '롯데시네마 도곡',
#  '떡깨비(공릉점)',
#  '진쇼니',
#  '노매드',
#  '누구나 홀딱 반한 닭 (구로항동점)',
#  '소리가있는주방',
#  '라이크잇',
#  '까페토미',
#  '유와이스쿠티',
#  '87닭강정 구로직영',
#  '포퀸스',
#  '멕시카나 세곡점',
#  '구구한식뷔폐',
#  '청파책가도',
#  '1970새마을포차(이수역점)',
#  '호가호가외식',
#  '사월의 새싹',
#  '희망컴퍼니',
#  '은마난로',
#  '마음이 약해서',
#  '에이스잭스포츠홀덤펍(AJ스포츠홀덤펍)',
#  '양가식탁',
#  '육대장 마곡점',
#  '청기와타운',
#  '어스키친 관악점',
#  '도담푸드',
#  '김경자 3代  진국',
#  '역전할머니맥주 발산역점',
#  '미스터피자 교대점',
#  '와이니하이',
#  '연남토마',
#  '불새',
#  '아바이 순대국',
#  '띠아 데 부리또',
#  '찜이로닭',
#  '모미락 은평점',
#  '투보가요리집',
#  '이소젠 네타',
#  '근린커피 브루잉',
#  '최씨한우곱창(역삼점)',
#  '순곱이네 서울대점',
#  '고기원칙 가산하스모나점',
#  '우리소육회마왕',
#  '화산공 꼬치집',
#  '바다회포차',
#  '송원F&B',
#  '카페712',
#  '금남정',
#  '새벽김밥',
# ...

# %%
shop_name = df["사업장명"]

# %%
len(shop_name)
# Out:
# 469871

# %%
shop_name.iloc[2045]
# Out:
# '두드림'

# %%
help(pd.unique)
# Out:
# Help on function unique in module pandas.core.algorithms:
#
# unique(values)
#     Hash table-based unique. Uniques are returned in order
#     of appearance. This does NOT sort.
#
#     Significantly faster than numpy.unique. Includes NA values.
#
#     Parameters
#     ----------
#     values : 1d array-like
#
#     Returns
#     -------
#     numpy.ndarray or ExtensionArray
#
#         The return can be:
#
#         * Index : when the input is an Index
#         * Categorical : when the input is a Categorical dtype
#         * ndarray : when the input is a Series/ndarray
#
#         Return numpy.ndarray or ExtensionArray.
#
#     See Also
#     --------
#     Index.unique
#     Series.unique
#
#     Examples
#     --------
#     >>> pd.unique(pd.Series([2, 1, 3, 3]))
#     array([2, 1, 3])
#
#     >>> pd.unique(pd.Series([2] + [1] * 5))
#     array([2, 1])
#
#     >>> pd.unique(pd.Series([pd.Timestamp('20160101'),
#     ...                     pd.Timestamp('20160101')]))
# ...

# %%
list(shop_name.unique())
# Out:
# ['일식동경',
#  '상해',
#  '미쿠',
#  '짱구',
#  '여름엔빙수겨울엔떡국',
#  '카페디퍼',
#  '메이크데이(MakeDay)',
#  '달의 작업실(Lalune)',
#  '숯칼 도산 숯닭갈비',
#  '테트리스찜닭 수유미아점',
#  '블러프라운지',
#  '싱싱호프',
#  '탐라정성돈카츠(탐정돈)',
#  '찬모일기',
#  '보스턴피자',
#  '올리브커피숍',
#  '먹거리 곱창전골',
#  '주문바다요',
#  '커피할루카',
#  '식껍선유도역점',
#  '반상회성수',
#  '무심',
#  '우주에프앤비 광진점',
#  '롯데시네마 도곡',
#  '떡깨비(공릉점)',
#  '진쇼니',
#  '노매드',
#  '누구나 홀딱 반한 닭 (구로항동점)',
#  '소리가있는주방',
#  '라이크잇',
#  '까페토미',
#  '유와이스쿠티',
#  '87닭강정 구로직영',
#  '포퀸스',
#  '멕시카나 세곡점',
#  '구구한식뷔폐',
#  '청파책가도',
#  '1970새마을포차(이수역점)',
#  '호가호가외식',
#  '사월의 새싹',
#  '희망컴퍼니',
#  '은마난로',
#  '마음이 약해서',
#  '에이스잭스포츠홀덤펍(AJ스포츠홀덤펍)',
#  '양가식탁',
#  '육대장 마곡점',
#  '청기와타운',
#  '어스키친 관악점',
#  '도담푸드',
#  '김경자 3代  진국',
#  '역전할머니맥주 발산역점',
#  '미스터피자 교대점',
#  '와이니하이',
#  '연남토마',
#  '불새',
#  '아바이 순대국',
#  '띠아 데 부리또',
#  '찜이로닭',
#  '모미락 은평점',
#  '투보가요리집',
#  '이소젠 네타',
#  '근린커피 브루잉',
#  '최씨한우곱창(역삼점)',
#  '순곱이네 서울대점',
#  '고기원칙 가산하스모나점',
#  '우리소육회마왕',
#  '화산공 꼬치집',
#  '바다회포차',
#  '송원F&B',
#  '카페712',
#  '금남정',
#  '새벽김밥',
# ...

# %%
shop_name = shop_name.astype("str")
count = 0
for i, w in enumerate(shop_name):
    if "두드림" in w:
        print(f"{i} : {w}")
        count += 1
print(f"total : {count}개")
# Out:
# 2045 : 두드림
# 224121 : 만두드림
# 311279 : 두드림치킨 천호
# 325370 : 두드림치킨
# 343871 : 두드림카페
# 345420 : 두드림
# 346183 : 두드림 치킨.비어
# 447441 : 두드림치킨
# total : 8개

# %%
shop_name_ = shop_name.fillna('Nan')
for i,w in enumerate(shop_name_):
    if '두드림' in w:
        print(i,w)
# Out:
# 2045 두드림
# 224121 만두드림
# 311279 두드림치킨 천호
# 325370 두드림치킨
# 343871 두드림카페
# 345420 두드림
# 346183 두드림 치킨.비어
# 447441 두드림치킨

# %%
shop_name[shop_name.str.contains('두드림')]
# Out:
# 2045            두드림
# 224121         만두드림
# 311279     두드림치킨 천호
# 325370        두드림치킨
# 343871        두드림카페
# 345420          두드림
# 346183    두드림 치킨.비어
# 447441        두드림치킨
# Name: 사업장명, dtype: object

# %%
idx = df["인허가일자"] > 20210101

# %%
df[idx].head(1)
# Out:
#     개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 12   3220000  3220000-101-2021-01287  20211027      NaN       1  영업/정상
#
#     상세영업상태코드 상세영업상태명  폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명  보증액  \
# 12         1      영업   NaN     NaN  ...        NaN        NaN     NaN  NaN
#
#     월세액 다중이용업소여부 시설총규모  전통업소지정번호 전통업소주된음식  홈페이지
# 12  NaN      NaN   NaN       NaN      NaN   NaN
#
# [1 rows x 44 columns]

# %%
close_idx = df["상세영업상태명"] == "폐업"

# %%
df[idx & close_idx & (df["업태구분명"] == "분식")].head(2)
# Out:
#        개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드 영업상태명  \
# 19249   3200000  3200000-101-2021-00120  20210225      NaN       3    폐업
# 51517   3200000  3200000-101-2021-00097  20210217      NaN       3    폐업
#
#        상세영업상태코드 상세영업상태명        폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수  \
# 19249         2      폐업  20210610.0     NaN  ...        NaN        NaN
# 51517         2      폐업  20210622.0     NaN  ...        NaN        NaN
#
#       건물소유구분명  보증액  월세액 다중이용업소여부 시설총규모  전통업소지정번호 전통업소주된음식  홈페이지
# 19249     NaN  NaN  NaN      NaN   NaN       NaN      NaN   NaN
# 51517     NaN  NaN  NaN      NaN   NaN       NaN      NaN   NaN
#
# [2 rows x 44 columns]

# %%
df.keys()
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
#        '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
#        '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
sp = df[["인허가일자", "상세영업상태명", "폐업일자", "소재지면적", "지번주소", "사업장명", "업태구분명", "영업장주변구분명"]]

# %%
sp
# Out:
#            인허가일자 상세영업상태명        폐업일자   소재지면적  \
# 0       20010214      영업         NaN     NaN
# 1       20010214      영업         NaN     NaN
# 2       20200602      영업         NaN   55.71
# 3       20040127      영업         NaN     NaN
# 4       20200602      영업         NaN   20.00
# ...          ...     ...         ...     ...
# 469866  19981230      영업         NaN   97.00
# 469867  19970909      영업         NaN   64.02
# 469868  19941121      폐업  20211026.0  117.58
# 469869  19921026      영업         NaN  112.20
# 469870  19920323      폐업  20211026.0   88.49
#
#                                        지번주소               사업장명  업태구분명 영업장주변구분명
# 0                  서울특별시 종로구 신문로1가 166-2번지                일식동경     일식       기타
# 1                     서울특별시 종로구 관철동 5-12번지                  상해     분식       기타
# 2                   서울특별시 관악구 신림동 1638-20번지                 미쿠     일식      NaN
# 3       서울특별시 종로구 창신동 583-95번지 외1필지 (지상1층)                  짱구     분식      NaN
# ...
