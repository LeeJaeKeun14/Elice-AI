# %% [markdown]
# # 클린 코드
#
# ## 코드 사용시 주의사항
#
# 코드 스멜(Code smell)
#
# 1. 긴 메서드
# 2. 중복 코드
# 3. 긴 매개 변수 목록
# 4. 너무 많은 주석
# 5. 전역 변수
# 6. 게으른 클래스
# 7. 거대한 클래스
#
# ## 우리는 보이스카웃
#
# - 코드른 수정할때는 이전보다 깨끗하게 정리하고 마무리하자.
#
# ## 읽기 좋은
#
# - ~~`a=1`~~
# - `a = 1`
#
# - ~~`x = x * 2 - 1`~~
# - `x = x*2 - 1`
#
# - ~~`hypot2 = x * x + (a - b)`~~
# - `hypot2 = x*x + (a-b)`
#
# ```python
# # income = (gross_wages +
# #           taxable_interest +
# #           (dividends - qualified) -
# #           ira_deduction -
# #           student_loan_interest)
#
# income = (gross_wages
#           + taxable_interest
#           + (dividends - qualified)
#           - ira_deduction
#           - student_loan_interest)
# ```
#
# ```python
# # my_list = [1, 2, 3,
# # 4, 5, 6,]
#
# result = some_function_that_takes_arguments(
#     'a', 'b', 'c',
#     'd', 'e', 'f',
# )
# ```
#
# - ~~`ham[lower + offset:upper + offset]`~~
# - `ham[lower + offset : upper + offset]`
#
# ```python
# # def complex(real, imag = 0.0):
# #     return magic(r = real, i = imag)
#
# def complex(real, imag=0.0):
#     return magic(r=real, i=imag)
# ```
#
# ## 의미 있는
#
# - 법적인 주석
# - 정보를 제공하는 주석
# - 의도를 설명하는 주석
# - 의미를 명료하게 밝히는 주석
# - 결과를 경고하는 주석
# - TODO 주석
# - 중요성 강조하는 주석
#
# - 나쁜 주석
#   - 주절거리는 주석
#   - 설명이 중복되는 주석
#   - 명확하지 않은 주석
#   - 의무적으로 다는 주석
#   - 이력을 기록하는 주석
#   - 당연한 사실 주석
#
# 스네이크 표기
# - 변수명
#   - ~~`coffeeprice`~~
#   - `coffee_price
#
# - 함수명
#   - ~~`def getprime()`~~
#   - `def get_prime()`
#
# 파스칼 표기
# - 클래스명
#   - ~~`class backgroundcolor:`~~
#   - `class BackgroundColor:`
#
# boolean
# - ~~`if greeting == True:`~~
# - ~~`if greeting id True`~~
# - `if greeting:`
#
# 빈 시퀸스
# - ~~`if len(seq):`~~
# - `if seq:`
#
# 접두사, 접미사
# - ~~`if foo[:3] == 'bar':`~~
# - `if foo.startswith('bar'):`
# - `if foo.endswith('bar'):`
#
# ## 효율적인
#
# - 중복 조건문
#   - point < 88 은 의미없는 조건문 이다.
# ```python
# # if point >= 88:
# #     print("A+")
# # elif point >= 77 and point < 88:
# #     print("A0")
# # else:
# #     print("B+")
# ```
#
# - 중복 코드는 함수화 시킨다
#
# - 상수
#   - 0일경우 방어, 1일 경우 공격 이라는 의미는 숫자만 보고 파악하기 힘들다.
#   - `ATTACK_STATUS, DEFENCE_STATUS = 1, 0`으로 사용
#
# - 함수는 하나의 기능만 하도록 구성
# - 함수의 매개변수는 묶어서 보내던가, 함수를 나눈다.
#
# - 다양함(확장성) vs 단순함(직관성)
#
# - 캡슐화
#   - 다른 언어의 private, public
# ```python
# class Human:
#     def __init__(self, name, birthday):
#         self.__name = name
#         self.__birthday = birthday
# ```
